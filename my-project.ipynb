# %%
range(20,10,18)
list = ['Milk', 'milk', 'bread']
print(list);
# Out:
# ['Milk', 'milk', 'bread']

# %%
L = []
n = int(input('Enter number of elements'))
for i in range(n):
    ele = int(input('Enter elements'))
    L += [ele]
print(L)
# Out:
# Enter number of elements 5
# Enter elements 2
# Enter elements 6
# Enter elements 2
# Enter elements 1
# Enter elements 7
# [2, 6, 2, 1, 7]

# %%
l = ['m','i','n','i']
l[1] = 'o'
l = l+['k']
l.append('a')
print(l)
# Out:
# ['m', 'o', 'n', 'i', 'k', 'a']

# %%
li = [2,5,3,4,8,]
li.sort()
print(li)
# Out:
# [2, 3, 4, 5, 8]

# %%
list = [1,2,3,4,5,6,7,8,9,0]
